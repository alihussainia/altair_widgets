# %% [markdown]
# <a href="https://colab.research.google.com/github/alihussainia/altair_widgets/blob/master/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install altair_widgets

# %%
# %%bash
# jupyter nbextension enable --py --sys-prefix widgetsnbextension
# jupyter nbextension enable --py --sys-prefix vega
# pip install altair_saver
# pip install jupyter pandas vega
# pip install --upgrade notebook
# jupyter nbextension install --sys-prefix --py vega
# apt-get update
# apt-get -qq install chromium-chromedriver

# %%
import altair_widgets

# %%
from vega_datasets import data as vds
stocks = vds.stocks()
stocks.head()
# Out:
#   symbol       date  price
# 0   MSFT 2000-01-01  39.81
# 1   MSFT 2000-02-01  36.35
# 2   MSFT 2000-03-01  43.22
# 3   MSFT 2000-04-01  28.37
# 4   MSFT 2000-05-01  25.45

# %%
from altair_widgets import interact_with
w = interact_with(stocks, ndims=3)

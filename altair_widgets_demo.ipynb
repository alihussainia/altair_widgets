# %% [markdown]
# <a href="https://colab.research.google.com/github/alihussainia/altair_widgets/blob/master/altair_widgets_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone "https://github.com/alihussainia/altair_widgets.git"
# Out:
# Cloning into 'altair_widgets'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 175 (delta 5), reused 11 (delta 4), pack-reused 158
# Receiving objects: 100% (175/175), 7.49 MiB | 14.28 MiB/s, done.
# Resolving deltas: 100% (77/77), done.

# %%
cd altair_widgets/

# %%
ls
# Out:
# altair_widgets/  LICENSE   MANIFEST.in  requirements.txt
# examples/        Makefile  README.md    setup.py

# %%
# !python setup.py sdist
# Out:
# running sdist
# running egg_info
# creating altair_widgets.egg-info
# writing altair_widgets.egg-info/PKG-INFO
# writing dependency_links to altair_widgets.egg-info/dependency_links.txt
# writing requirements to altair_widgets.egg-info/requires.txt
# writing top-level names to altair_widgets.egg-info/top_level.txt
# writing manifest file 'altair_widgets.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# ...
# writing manifest file 'altair_widgets.egg-info/SOURCES.txt'
# running check
# creating altair_widgets-0.2.2
# creating altair_widgets-0.2.2/altair_widgets
# creating altair_widgets-0.2.2/altair_widgets.egg-info
# creating altair_widgets-0.2.2/altair_widgets/tests
# creating altair_widgets-0.2.2/examples
# copying files to altair_widgets-0.2.2...
# copying .gitignore -> altair_widgets-0.2.2
# copying .travis.yml -> altair_widgets-0.2.2
# copying LICENSE -> altair_widgets-0.2.2
# copying MANIFEST.in -> altair_widgets-0.2.2
# copying Makefile -> altair_widgets-0.2.2
# ...

# %%
# !pip install .
# Out:
# Processing /content/drive/My Drive/altair_widgets/altair_widgets/altair_widget/altair_widgets
# ...
#   Created wheel for altair-widgets: filename=altair_widgets-0.2.2-cp36-none-any.whl size=6657 sha256=91abafcae1b9529c2fd3e724d17b29b42024a72419094105b4aca687b1d6f7de
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mplffuvg/wheels/61/e7/6c/37f2700ee26cb7cbb2b4cf374c373bfc36f376a4bc6c083715
# Successfully built altair-widgets
# ...

# %%
import altair_widgets

# %%
from vega_datasets import data as vds
stocks = vds.stocks()
stocks.head()
# Out:
#   symbol       date  price
# 0   MSFT 2000-01-01  39.81
# 1   MSFT 2000-02-01  36.35
# 2   MSFT 2000-03-01  43.22
# 3   MSFT 2000-04-01  28.37
# 4   MSFT 2000-05-01  25.45

# %%
from altair_widget import interact_with
w = interact_with(stocks, ndims=3)
